# %%
# All imports


from prettyprinter import pprint 

import numpy as np
import pandas as pd
import json


import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = [15, 10]
import seaborn as sns
sns.set_style('dark')

import tensorly as tl
from tensorly.decomposition import parafac,tucker

import scipy,sklearn
import  sklearn.decomposition

import time

# %%
#print datatime - records when last run
import datetime
datetime.datetime.now().strftime('%Y-%m-%d || %H:%M')
# Out:
# '2021-07-08 || 19:30'

# %%
# import data
# Unzip if not already done
import os,shutil
if not 'mumbai-hexclusters-2019-4-All-HourlyAggregate.csv' in os.listdir('../data/'):
    shutil.unpack_archive(filename="../mumbai-hexclusters-2019-4-All-HourlyAggregate.zip",extract_dir='../data/')

# %%
df = pd.read_csv('../data/mumbai-hexclusters-2019-4-All-HourlyAggregate.csv')

# %%
df.head()
# Out:
#    sourceid  dstid  hod  mean_travel_time  standard_deviation_travel_time  \
# 0       171    206   15           2949.31                         1139.79
# 1       255    439   10           5045.33                          839.06
# 2       110     18    0           2932.71                          537.47
# 3        38      7    5           2690.29                          741.75
# 4       277    219   10           4848.73                          730.67
#
#    geometric_mean_travel_time  geometric_standard_deviation_travel_time
# 0                     2772.51                                      1.40
# 1                     4978.27                                      1.18
# 2                     2886.25                                      1.19
# 3                     2591.41                                      1.31
# 4                     4796.48                                      1.16

# %%
origins = sorted(df.sourceid.unique())
destinations = sorted(df.dstid.unique())
hods = sorted(df.hod.unique())

origin_max = max(origins)
dest_max = max(destinations)
hod_max = max(hods)

list(map(min,[origins,destinations,hods]))

# Make numpy tensor
nptensor = np.zeros(     (   dest_max, origin_max, hod_max+1  )      ) 
#nptensor.fill(-99)
def transfer(x):
    nptensor[x.dstid-1 ,x.sourceid-1, x.hod] = x.mean_travel_time
    return 0

df.pipe(transfer)
# Out:
# 0

# %%
print(nptensor[300,3,10])
# verify if nptensor has right data
df[df.sourceid==4] [ df.dstid==301 ] [ df.hod==10]
# Out:
# 1718.02
# <ipython-input-27-82e206264241>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.sourceid==4] [ df.dstid==301 ] [ df.hod==10]
# <ipython-input-27-82e206264241>:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df[df.sourceid==4] [ df.dstid==301 ] [ df.hod==10]
#          sourceid  dstid  hod  mean_travel_time  \
# 1261503         4    301   10           1718.02
#
#          standard_deviation_travel_time  geometric_mean_travel_time  \
# 1261503                           619.9                     1633.91
#
#          geometric_standard_deviation_travel_time
# 1261503                                      1.35

# %%
# create tensorly data
#nptensor -= nptensor.mean()
tensor = tl.tensor(nptensor)

# %%
# parafac with ortogonality
def tensorrank2variance(k, algo):
    _verbose=0
    _iters = 100
    _mask = (nptensor!=0)*1
    now = time.time()
    if algo=='parafac':
        _factors,_errors = parafac(tensor, rank=k, mask=_mask , return_errors=True, orthogonalise=False, n_iter_max = _iters, verbose=_verbose,linesearch=True)
        _weights, _components = _factors
        _params = sum(tensor.shape)*k
        unmasked_reconstruction_error = tl.norm(tensor - tl.cp_to_tensor((_weights, _components)))
        masked_reconstruction_error = tl.norm(tensor - tl.cp_to_tensor((_weights, _components)) * _mask)
        
       
        #print(_weights)
    
    elif algo=='parafacortho':
        _factors,_errors = parafac(tensor, rank=k, mask=_mask,return_errors=True, orthogonalise=True, n_iter_max=_iters, verbose=_verbose)
        _weights, _components = _factors
        _params = sum(tensor.shape)*k
        unmasked_reconstruction_error = tl.norm(tensor - tl.cp_to_tensor((_weights, _components)))
        masked_reconstruction_error = tl.norm(tensor - tl.cp_to_tensor((_weights, _components))  * _mask  )
        
        #print(_weights)
        
        
        
    elif algo=='tucker':
        _core, _factors, =  tucker(tensor, rank=k,mask=_mask, verbose = 1)
        _params = sum(tensor.shape)*k + k**3
        masked_reconstruction_error = tl.norm(  (   tensor - tl.tucker_to_tensor((_core, _factors))   ) * _mask  )
        unmasked_reconstruction_error = tl.norm(  (   tensor - tl.tucker_to_tensor((_core, _factors))   ) )
    
        

    
    #print(reconstruction_error / tl.norm(tensor))
    #print(errors)

    # total_var = norm**2 = explained_var + error**2
    # => total_var = explained_var + error**2
    # => explained_var = total_var - error**2
    # => explained_var_normalized = explained_var / total_var

    total_variance = tl.norm(tensor)**2
    
    masked_explained_variance = total_variance - masked_reconstruction_error**2
    masked_explained_variance_normalized = masked_explained_variance / total_variance
    
    unmasked_explained_variance = total_variance - unmasked_reconstruction_error**2
    unmasked_explained_variance_normalized = unmasked_explained_variance / total_variance
    
    print()
    print(f'masked_error -> {masked_reconstruction_error}')
    print(f'unmasked_error -> {unmasked_reconstruction_error}')
    print(f'{algo} - rank-{k} masked_explained->',masked_explained_variance_normalized)
    print(f'{algo} - rank-{k} unmasked_explained->',unmasked_explained_variance_normalized)
    
    took = time.time() - now
    print(f'{algo} - rank-{k} took->',took)
    print()
    return masked_explained_variance_normalized, took,_params,unmasked_explained_variance_normalized

# %%
total = nptensor.shape[0]*nptensor.shape[1]*nptensor.shape[2]
missing = (nptensor==0).sum()
print(missing,total)
print('Missing percentage:',missing*100/total)
# Out:
# 5907886 11592600
# Missing percentage: 50.962562324241325

# %%
explained_parafac = [tensorrank2variance(k, 'parafac') for k in range(1,11)]
# Out:
# masked_error -> 3195006.139464091
# unmasked_error -> 6793725.68706056
# parafac - rank-1 masked_explained-> 0.8488235367364411
# parafac - rank-1 unmasked_explained-> 0.3164712262920905
# parafac - rank-1 took-> 78.53802394866943
#
#
# masked_error -> 2202061.5478243344
# unmasked_error -> 10613121.76686865
# parafac - rank-2 masked_explained-> 0.928187558274733
# parafac - rank-2 unmasked_explained-> -0.6681191992124313
# parafac - rank-2 took-> 90.42268133163452
#
#
# masked_error -> 1405304.7756109093
# unmasked_error -> 11363243.155939577
# parafac - rank-3 masked_explained-> 0.9707529659257534
# parafac - rank-3 unmasked_explained-> -0.9122531582947365
# parafac - rank-3 took-> 104.65268993377686
#
#
# masked_error -> 1133380.831310183
# unmasked_error -> 9758356.531417815
# parafac - rank-4 masked_explained-> 0.9809764084272193
# parafac - rank-4 unmasked_explained-> -0.4102436398995423
# parafac - rank-4 took-> 119.61777520179749
#
#
# masked_error -> 981101.3771946905
# unmasked_error -> 9679058.089139586
# parafac - rank-5 masked_explained-> 0.9857449561513448
# parafac - rank-5 unmasked_explained-> -0.3874168972913212
# parafac - rank-5 took-> 132.73442220687866
#
#
# masked_error -> 861042.2255496694
# unmasked_error -> 9309775.247504756
# parafac - rank-6 masked_explained-> 0.989020319910137
# parafac - rank-6 unmasked_explained-> -0.2835688825272491
# parafac - rank-6 took-> 146.5804581642151
#
#
# masked_error -> 832868.7880599286
# unmasked_error -> 8993252.326139834
# parafac - rank-7 masked_explained-> 0.98972707869902
# parafac - rank-7 unmasked_explained-> -0.19777251790237743
# parafac - rank-7 took-> 159.9081997871399
#
#
# masked_error -> 805324.0413426873
# unmasked_error -> 8713859.391541991
# parafac - rank-8 masked_explained-> 0.9903953373516804
# parafac - rank-8 unmasked_explained-> -0.12450627296832015
# parafac - rank-8 took-> 175.49459099769592
#
#
# masked_error -> 760225.6952033569
# unmasked_error -> 8628981.727253895
# parafac - rank-9 masked_explained-> 0.9914409438456967
# parafac - rank-9 unmasked_explained-> -0.10270637543883783
# parafac - rank-9 took-> 190.8948314189911
#
#
# masked_error -> 739661.1067899435
# unmasked_error -> 8415783.564298455
# parafac - rank-10 masked_explained-> 0.9918977366902932
# parafac - rank-10 unmasked_explained-> -0.048889897650756686
# parafac - rank-10 took-> 204.11504793167114

# %%
explained_parafacortho = [tensorrank2variance(k, 'parafacortho') for k in range(1,11)]
# Out:
# masked_error -> 3195069.9459396005
# unmasked_error -> 6774157.779642154
# parafacortho - rank-1 masked_explained-> 0.8488174984797374
# parafacortho - rank-1 unmasked_explained-> 0.3204030793289713
# parafacortho - rank-1 took-> 62.30705213546753
#
#
# masked_error -> 2220219.044739522
# unmasked_error -> 9205936.976935519
# parafacortho - rank-2 masked_explained-> 0.9269983906939886
# parafacortho - rank-2 unmasked_explained-> -0.2550955267017974
# parafacortho - rank-2 took-> 69.6415286064148
#
#
# masked_error -> 1444700.0273431106
# unmasked_error -> 9850888.138744403
# parafacortho - rank-3 masked_explained-> 0.969090203282905
# parafacortho - rank-3 unmasked_explained-> -0.437115130522124
# parafacortho - rank-3 took-> 79.37206363677979
#
#
# masked_error -> 1167263.9219311033
# unmasked_error -> 9068636.213349374
# parafacortho - rank-4 masked_explained-> 0.9798219631063813
# parafacortho - rank-4 unmasked_explained-> -0.21793678646565504
# parafacortho - rank-4 took-> 87.23639392852783
#
#
# masked_error -> 991755.7112381005
# unmasked_error -> 9035505.298885403
# parafacortho - rank-5 masked_explained-> 0.9854336679052836
# parafacortho - rank-5 unmasked_explained-> -0.20905394020294216
# parafacortho - rank-5 took-> 96.10333895683289
#
#
# masked_error -> 904167.659119606
# unmasked_error -> 8502982.997787047
# parafacortho - rank-6 masked_explained-> 0.9878929391680525
# parafacortho - rank-6 unmasked_explained-> -0.07073847424686579
# parafacortho - rank-6 took-> 102.88448143005371
#
#
# masked_error -> 879042.4696344225
# unmasked_error -> 8199310.057669957
# parafacortho - rank-7 masked_explained-> 0.9885564570854531
# parafacortho - rank-7 unmasked_explained-> 0.004375887364557975
# parafacortho - rank-7 took-> 110.21458864212036
#
#
# masked_error -> 894228.1523903843
# unmasked_error -> 7811695.500389698
# parafacortho - rank-8 masked_explained-> 0.9881576616959443
# parafacortho - rank-8 unmasked_explained-> 0.09628519070394714
# parafacortho - rank-8 took-> 119.71942925453186
#
#
# masked_error -> 800761.057050498
# unmasked_error -> 7919344.237527154
# parafacortho - rank-9 masked_explained-> 0.9905038694784029
# parafacortho - rank-9 unmasked_explained-> 0.07120636747285856
# parafacortho - rank-9 took-> 127.73037791252136
#
#
# masked_error -> 752784.0711438172
# unmasked_error -> 7981311.894094824
# parafacortho - rank-10 masked_explained-> 0.9916076878568276
# parafacortho - rank-10 unmasked_explained-> 0.05661416304593446
# parafacortho - rank-10 took-> 136.45082879066467

# %%
explained_tucker = [tensorrank2variance(k, 'tucker') for k in range(1,11)]
# Out:
# reconstruction error=0.3017031133596365, variation=-0.18856043340724155.
# reconstruction error=0.380274483539707, variation=-0.07857137018007049.
# reconstruction error=0.4284968909116662, variation=-0.04822240737195921.
# reconstruction error=0.46167694341719817, variation=-0.033180052505531965.
# reconstruction error=0.48595909750451577, variation=-0.024282154087317598.
# reconstruction error=0.5044549973691715, variation=-0.018495899864655774.
# reconstruction error=0.518953930320279, variation=-0.01449893295110749.
# reconstruction error=0.530572501325279, variation=-0.011618571004999967.
# reconstruction error=0.5400487778213883, variation=-0.00947627649610927.
# reconstruction error=0.5478919623715732, variation=-0.007843184550184956.
# reconstruction error=0.5544652307800562, variation=-0.006573268408482935.
# reconstruction error=0.5600345922160908, variation=-0.005569361436034592.
# reconstruction error=0.5647991843675, variation=-0.00476459215140923.
# reconstruction error=0.5689108305346376, variation=-0.004111646167137661.
# reconstruction error=0.5724870920548965, variation=-0.0035762615202588055.
# reconstruction error=0.5756202266399415, variation=-0.00313313458504505.
# reconstruction error=0.5783834852523384, variation=-0.0027632586123969016.
# reconstruction error=0.5808356303131691, variation=-0.0024521450608306905.
# reconstruction error=0.583024236377195, variation=-0.002188606064025933.
# reconstruction error=0.5849881397097089, variation=-0.001963903332513839.
# reconstruction error=0.5867592817905554, variation=-0.0017711420808464995.
# reconstruction error=0.588364114062727, variation=-0.0016048322721716746.
# reconstruction error=0.5898246803395187, variation=-0.0014605662767916971.
# reconstruction error=0.5911594592413143, variation=-0.0013347789017955636.
# reconstruction error=0.5923840258370748, variation=-0.0012245665957605345.
# reconstruction error=0.5935115755909436, variation=-0.0011275497538687507.
# reconstruction error=0.5945533424020824, variation=-0.0010417668111387668.
# reconstruction error=0.5955189344523225, variation=-0.0009655920502401605.
# reconstruction error=0.5964166057393943, variation=-0.000897671287071744.
# reconstruction error=0.5972534769034634, variation=-0.000836871164069164.
# reconstruction error=0.5980357157965323, variation=-0.0007822388930688318.
# reconstruction error=0.598768685884816, variation=-0.0007329700882837686.
# reconstruction error=0.5994570687948749, variation=-0.0006883829100589045.
# reconstruction error=0.6001049659608353, variation=-0.000647897165960365.
# reconstruction error=0.600715983292156, variation=-0.0006110173313207401.
# reconstruction error=0.6012933019795647, variation=-0.0005773186874086234.
# reconstruction error=0.601839737933033, variation=-0.0005464359534683716.
# reconstruction error=0.6023577918571297, variation=-0.0005180539240966509.
# reconstruction error=0.6028496915843266, variation=-0.0004918997271968761.
# reconstruction error=0.6033174279818604, variation=-0.00046773639753383556.
# reconstruction error=0.6037627855049001, variation=-0.00044535752303975773.
# reconstruction error=0.60418736827432, variation=-0.0004245827694198123.
# reconstruction error=0.6045926224009555, variation=-0.0004052541266355014.
# reconstruction error=0.6049798551518671, variation=-0.0003872327509116813.
# reconstruction error=0.6053502514515927, variation=-0.00037039629972557275.
# reconstruction error=0.6057048881278682, variation=-0.0003546366762754438.
# reconstruction error=0.6060447462429895, variation=-0.0003398581151213831.
# reconstruction error=0.6063707217959841, variation=-0.0003259755529945174.
# reconstruction error=0.6066836350345826, variation=-0.00031291323859850007.
# reconstruction error=0.6069842385779076, variation=-0.000300603543325062.
# reconstruction error=0.6072732245192096, variation=-0.00028898594130200017.
# reconstruction error=0.6075512306517222, variation=-0.0002780061325126093.
# reconstruction error=0.6078188459388725, variation=-0.00026761528715024685.
# reconstruction error=0.6080766153317562, variation=-0.00025776939288368883.
# reconstruction error=0.6083250440215441, variation=-0.0002484286897879162.
# reconstruction error=0.6085646012015509, variation=-0.0002395571800067886.
# reconstruction error=0.6087957234029269, variation=-0.00023112220137599948.
# reconstruction error=0.6090188174587557, variation=-0.00022309405582887631.
# reconstruction error=0.6092342631436256, variation=-0.00021544568486986382.
# reconstruction error=0.6094424155291883, variation=-0.00020815238556270987.
# reconstruction error=0.609643607090625, variation=-0.0002011915614367199.
# reconstruction error=0.6098381495942291, variation=-0.0001945425036040671.
# reconstruction error=0.6100263357922506, variation=-0.0001881861980215227.
# reconstruction error=0.6102084409476835, variation=-0.00018210515543282124.
# reconstruction error=0.6103847242087189, variation=-0.00017628326103547032.
# reconstruction error=0.6105554298500594, variation=-0.00017070564134047395.
# reconstruction error=0.6107207883960557, variation=-0.00016535854599630806.
# reconstruction error=0.6108810176388093, variation=-0.00016022924275360673.
# reconstruction error=0.6110363235626921, variation=-0.00015530592388279807.
# reconstruction error=0.6111869011853714, variation=-0.0001505776226793376.
# reconstruction error=0.6113329353241944, variation=-0.00014603413882297023.
# reconstruction error=0.6114746012957203, variation=-0.0001416659715258728.
# reconstruction error=0.6116120655552946, variation=-0.00013746425957428254.
# reconstruction error=0.6117454862827417, variation=-0.00013342072744715328.
# reconstruction error=0.6118750139195338, variation=-0.00012952763679208168.
# reconstruction error=0.6120007916622445, variation=-0.00012577774271071984.
# reconstruction error=0.6121229559164908, variation=-0.00012216425424627086.
# reconstruction error=0.6122416367151493, variation=-0.00011868079865851033.
# reconstruction error=0.6123569581042092, variation=-0.00011532138905989697.
# reconstruction error=0.6124690384992426, variation=-0.00011208039503340927.
# reconstruction error=0.6125779910151926, variation=-0.00010895251595000044.
# reconstruction error=0.6126839237718639, variation=-0.00010593275667125646.
# reconstruction error=0.612786940177257, variation=-0.00010301640539311929.
# reconstruction error=0.6128871391907148, variation=-0.00010019901345781346.
# reconstruction error=0.6129846155675772, variation=-9.747637686241539e-05.
# converged in 86 iterations.
#
# masked_error -> 3195107.4228619584
# unmasked_error -> 6767383.370889815
# tucker - rank-1 masked_explained-> 0.8488139518355661
# tucker - rank-1 unmasked_explained-> 0.3217616438791914
# tucker - rank-1 took-> 31.58483624458313
#
# reconstruction error=0.3372790951245982, variation=-0.14201275370654048.
# reconstruction error=0.414280629503636, variation=-0.07700153437903778.
# reconstruction error=0.46901157331864807, variation=-0.05473094381501209.
# reconstruction error=0.512357838409112, variation=-0.04334626509046391.
# reconstruction error=0.5487363221247211, variation=-0.036378483715609145.
# reconstruction error=0.580330005101382, variation=-0.031593682976660875.
# reconstruction error=0.6083525982057297, variation=-0.028022593104347737.
# reconstruction error=0.6335384592613257, variation=-0.02518586105559595.
# reconstruction error=0.6563660306077769, variation=-0.022827571346451192.
# reconstruction error=0.6771708181387135, variation=-0.02080478753093662.
# reconstruction error=0.6962057811421445, variation=-0.019034963003430994.
# reconstruction error=0.7136741899279085, variation=-0.017468408785764056.
# reconstruction error=0.7297473824380603, variation=-0.016073192510151713.
# reconstruction error=0.7445742352687648, variation=-0.014826852830704507.
# reconstruction error=0.7582862597095973, variation=-0.013712024440832526.
# reconstruction error=0.7710005714303789, variation=-0.012714311720781635.
# reconstruction error=0.7828220305645092, variation=-0.011821459134130241.
# reconstruction error=0.7938453581567376, variation=-0.01102332759222846.
# reconstruction error=0.8041576667416128, variation=-0.010312308584875196.
# reconstruction error=0.8138404982891827, variation=-0.009682831547569881.
# reconstruction error=0.8229673351819048, variation=-0.00912683689272209.
# reconstruction error=0.8315962992479632, variation=-0.008628964066058398.
# reconstruction error=0.8397701718304186, variation=-0.008173872582455388.
# reconstruction error=0.8475230776929819, variation=-0.007752905862563275.
# reconstruction error=0.8548843566141912, variation=-0.007361278921209302.
# reconstruction error=0.861880864644448, variation=-0.006996508030256865.
# reconstruction error=0.8685384034800925, variation=-0.006657538835644461.
# reconstruction error=0.8748819458510019, variation=-0.006343542370909394.
# reconstruction error=0.8809352425294597, variation=-0.006053296678457776.
# reconstruction error=0.8867204193401546, variation=-0.005785176810694903.
# reconstruction error=0.8922577802706507, variation=-0.005537360930496171.
# reconstruction error=0.897565796352063, variation=-0.005308016081412292.
# reconstruction error=0.9026612034007373, variation=-0.005095407048674283.
# reconstruction error=0.9075591473489273, variation=-0.004897943948189987.
# reconstruction error=0.9122733416370674, variation=-0.004714194288140128.
# reconstruction error=0.9168162193391699, variation=-0.004542877702102488.
# reconstruction error=0.9211990728656403, variation=-0.004382853526470387.
# reconstruction error=0.9254321791376262, variation=-0.00423310627198592.
# reconstruction error=0.9295249104198474, variation=-0.004092731282221207.
# reconstruction error=0.9334858319284929, variation=-0.003960921508645465.
# reconstruction error=0.9373227876229037, variation=-0.003836955694410782.
# reconstruction error=0.9410429755999279, variation=-0.003720187977024225.
# reconstruction error=0.9446530144060169, variation=-0.003610038806089011.
# reconstruction error=0.9481590014409332, variation=-0.003505987034916336.
# reconstruction error=0.9515665644819902, variation=-0.003407563041056938.
# reconstruction error=0.954880907222671, variation=-0.0033143427406808756.
# reconstruction error=0.9581068495988342, variation=-0.003225942376163138.
# reconstruction error=0.9612488635702136, variation=-0.003142013971379365.
# reconstruction error=0.9643111049335731, variation=-0.0030622413633595302.
# reconstruction error=0.9672974416651552, variation=-0.0029863367315821066.
# reconstruction error=0.9702114792224683, variation=-0.0029140375573131205.
# reconstruction error=0.9730565831774312, variation=-0.0028451039549628465.
# reconstruction error=0.9758358995029919, variation=-0.002779316325560721.
# reconstruction error=0.9785523727926646, variation=-0.0027164732896727273.
# reconstruction error=0.9812087626555963, variation=-0.0026563898629317073.
# reconstruction error=0.9838076584982612, variation=-0.002598895842664928.
# reconstruction error=0.9863514928766373, variation=-0.0025438343783760198.
# reconstruction error=0.9888425535793485, variation=-0.002491060702711212.
# reconstruction error=0.9912829945821205, variation=-0.0024404410027720758.
# reconstruction error=0.9936748459963475, variation=-0.002391851414226931.
# reconstruction error=0.9960200231196158, variation=-0.002345177123268316.
# reconstruction error=0.9983203346829189, variation=-0.0023003115633031257.
# reconstruction error=1.00057749037802, variation=-0.0022571556951010985.
# reconstruction error=1.0027931077385686, variation=-0.0022156173605485385.
# reconstruction error=1.0049687184400242, variation=-0.002175610701455666.
# reconstruction error=1.007105774076016, variation=-0.002137055635991869.
# reconstruction error=1.0092056514622454, variation=-0.0020998773862292985.
# reconstruction error=1.011269657513327, variation=-0.0020640060510817015.
# reconstruction error=1.013299033733037, variation=-0.0020293762197098886.
# reconstruction error=1.015294960354006, variation=-0.001995926620969035.
# reconstruction error=1.0172585601590667, variation=-0.0019635998050606673.
# reconstruction error=1.0191909020131018, variation=-0.0019323418540351245.
# reconstruction error=1.0210930041312314, variation=-0.0019021021181295783.
# reconstruction error=1.0229658371064865, variation=-0.0018728329752550898.
# reconstruction error=1.024810326717915, variation=-0.0018444896114284681.
# reconstruction error=1.0266273565378157, variation=-0.0018170298199007284.
# reconstruction error=1.0284177703550914, variation=-0.0017904138172757378.
# reconstruction error=1.0301823744300118, variation=-0.0017646040749204062.
# reconstruction error=1.0319219395942132, variation=-0.0017395651642013732.
# reconstruction error=1.0336372032084784, variation=-0.0017152636142652167.
# reconstruction error=1.0353288709896835, variation=-0.0016916677812051084.
# reconstruction error=1.0369976187171965, variation=-0.0016687477275130203.
# reconstruction error=1.0386440938281525, variation=-0.0016464751109559472.
# reconstruction error=1.0402689169101318, variation=-0.0016248230819793097.
# reconstruction error=1.0418726830990386, variation=-0.0016037661889067856.
# reconstruction error=1.0434559633893048, variation=-0.0015832802902662202.
# reconstruction error=1.045019305862898, variation=-0.0015633424735932433.
# reconstruction error=1.0465632368430706, variation=-0.001543930980172581.
# reconstruction error=1.0480882619783203, variation=-0.001525025135249658.
# reconstruction error=1.049594867261526, variation=-0.0015066052832057863.
# reconstruction error=1.0510835199888477, variation=-0.001488652727321682.
# reconstruction error=1.0525546696625954, variation=-0.0014711496737476182.
# reconstruction error=1.054008748841921, variation=-0.001454079179325607.
# reconstruction error=1.0554461739449248, variation=-0.0014374251030038199.
# reconstruction error=1.0568673460054023, variation=-0.001421172060477538.
# reconstruction error=1.0582726513873033, variation=-0.0014053053819009786.
# reconstruction error=1.0596624624596749, variation=-0.0013898110723715718.
# reconstruction error=1.0610371382346593, variation=-0.0013746757749844019.
#
# masked_error -> 2215960.934951569
# unmasked_error -> 9275460.37469666
# tucker - rank-2 masked_explained-> 0.9272781385708654
# tucker - rank-2 unmasked_explained-> -0.2741241154557368
# tucker - rank-2 took-> 34.999476194381714
#
# reconstruction error=0.4179718328738468, variation=-0.1156643878993322.
# reconstruction error=0.48949931358484294, variation=-0.07152748071099613.
# reconstruction error=0.5421111496248425, variation=-0.05261183603999958.
# reconstruction error=0.5841457847871159, variation=-0.04203463516227335.
# reconstruction error=0.6193533715539227, variation=-0.0352075867668068.
# reconstruction error=0.6497295933192311, variation=-0.03037622176530841.
# reconstruction error=0.6764677909090562, variation=-0.026738197589825097.
# reconstruction error=0.7003461084248528, variation=-0.02387831751579661.
# reconstruction error=0.7219060690983556, variation=-0.021559960673502854.
# reconstruction error=0.7415433940127811, variation=-0.01963732491442549.
# reconstruction error=0.7595581274928808, variation=-0.01801473348009963.
# reconstruction error=0.7761843049482403, variation=-0.016626177455359548.
# reconstruction error=0.7916085802658165, variation=-0.015424275317576175.
# reconstruction error=0.8059825087099626, variation=-0.014373928444146089.
# reconstruction error=0.819430978506385, variation=-0.013448469796422446.
# reconstruction error=0.8320581923640762, variation=-0.012627213857691166.
# reconstruction error=0.8439520276113353, variation=-0.011893835247259066.
# reconstruction error=0.8551872873316888, variation=-0.011235259720353552.
# reconstruction error=0.8658281717032861, variation=-0.01064088437159727.
# reconstruction error=0.8759301881007184, variation=-0.010102016397432356.
# reconstruction error=0.8855416492010588, variation=-0.00961146110034039.
# reconstruction error=0.8947048635337429, variation=-0.009163214332684078.
# reconstruction error=0.9034570931892972, variation=-0.008752229655554333.
# reconstruction error=0.9118313332539675, variation=-0.008374240064670246.
# reconstruction error=0.9198569536496187, variation=-0.008025620395651245.
# reconstruction error=0.9275602343613071, variation=-0.007703280711688354.
# reconstruction error=0.9349648181672376, variation=-0.007404583805930565.
# reconstruction error=0.9420920999275255, variation=-0.0071272817602878735.
# reconstruction error=0.9489615672045858, variation=-0.006869467277060282.
# reconstruction error=0.955591101942032, variation=-0.006629534737446208.
# reconstruction error=0.9619972444075804, variation=-0.006406142465548381.
# reconstruction error=0.9681954044085382, variation=-0.006198160000957853.
# reconstruction error=0.9741999778071867, variation=-0.006004573398648461.
# reconstruction error=0.9800242974541017, variation=-0.005824319646914988.
# reconstruction error=0.985680356689495, variation=-0.0056560592353933625.
# reconstruction error=0.9911783549858223, variation=-0.0054979982963272445.
# reconstruction error=0.9965263216274741, variation=-0.0053479666416518246.
# reconstruction error=1.0017301731561972, variation=-0.005203851528723047.
# reconstruction error=1.006794322356231, variation=-0.005064149200033841.
# reconstruction error=1.0117225447040332, variation=-0.004928222347802214.
# reconstruction error=1.016518676504812, variation=-0.004796131800778758.
# reconstruction error=1.0211869498909858, variation=-0.004668273386173816.
# reconstruction error=1.0257320301001052, variation=-0.004545080209119368.
# reconstruction error=1.030158900891377, variation=-0.0044268707912717975.
# reconstruction error=1.0344727046681994, variation=-0.004313803776822445.
# reconstruction error=1.0386785907359244, variation=-0.004205886067724984.
# reconstruction error=1.042781593346407, variation=-0.004103002610482687.
# reconstruction error=1.0467865453203584, variation=-0.004004951973951343.
# reconstruction error=1.0506980248926472, variation=-0.003911479572288767.
# reconstruction error=1.0545203295861902, variation=-0.003822304693543055.
# reconstruction error=1.0582574699016802, variation=-0.003737140315489995.
# reconstruction error=1.061913176240121, variation=-0.0036557063384408117.
# reconstruction error=1.0654909138061526, variation=-0.0035777375660315247.
# reconstruction error=1.0689939016697139, variation=-0.003502987863561291.
# reconstruction error=1.0724251333991082, variation=-0.0034312317293943018.
# reconstruction error=1.0757873976299386, variation=-0.003362264230830414.
# reconstruction error=1.0790832976136537, variation=-0.003295899983715156.
# reconstruction error=1.082315269248059, variation=-0.0032319716344053617.
# reconstruction error=1.0854855973868076, variation=-0.0031703281387485127.
# reconstruction error=1.0885964304049998, variation=-0.0031108330181921495.
# reconstruction error=1.0916497931012887, variation=-0.003053362696288975.
# reconstruction error=1.0946475980703523, variation=-0.0029978049690635444.
# reconstruction error=1.0975916557019618, variation=-0.0029440576316095424.
# reconstruction error=1.1004836829666156, variation=-0.0028920272646537626.
# reconstruction error=1.1033253111407515, variation=-0.002841628174135913.
# reconstruction error=1.1061180926120733, variation=-0.0027927814713217813.
# reconstruction error=1.108863506890783, variation=-0.002745414278709779.
# reconstruction error=1.1115629659371555, variation=-0.0026994590463724766.
# reconstruction error=1.1142178189013014, variation=-0.002654852964145915.
# reconstruction error=1.1168293563574845, variation=-0.002611537456183033.
# reconstruction error=1.119398814103281, variation=-0.002569457745796422.
# reconstruction error=1.1219273765833517, variation=-0.0025285624800708284.
# reconstruction error=1.1244161799884802, variation=-0.00248880340512847.
# reconstruction error=1.1268663150726872, variation=-0.0024501350842069947.
# reconstruction error=1.1292788297246508, variation=-0.002412514651963571.
# reconstruction error=1.13165473132408, variation=-0.002375901599429131.
# reconstruction error=1.133994988908952, variation=-0.0023402575848721074.
# reconstruction error=1.136300535175661, variation=-0.00230554626670898.
# reconstruction error=1.1385722683307773, variation=-0.0022717331551163067.
# reconstruction error=1.140811053810419, variation=-0.002238785479641736.
# reconstruction error=1.143017725880919, variation=-0.002206672070500071.
# reconstruction error=1.1451930891326134, variation=-0.0021753632516943178.
# reconstruction error=1.1473379198768703, variation=-0.002144830744256865.
# reconstruction error=1.1494529674552627, variation=-0.002115047578392426.
# reconstruction error=1.1515389554686024, variation=-0.0020859880133397013.
# reconstruction error=1.1535965829325783, variation=-0.002057627463975864.
# reconstruction error=1.1556265253660123, variation=-0.0020299424334340177.
# reconstruction error=1.1576294358169958, variation=-0.0020029104509835527.
# reconstruction error=1.1596059458316508, variation=-0.001976510014654931.
# reconstruction error=1.1615566663697272, variation=-0.0019507205380764336.
# reconstruction error=1.1634821886708238, variation=-0.0019255223010965494.
# reconstruction error=1.1653830850746654, variation=-0.001900896403841612.
# reconstruction error=1.167259909798559, variation=-0.0018768247238936109.
# reconstruction error=1.1691131996748225, variation=-0.001853289876263542.
# reconstruction error=1.1709434748508036, variation=-0.0018302751759811109.
# reconstruction error=1.172751239453829, variation=-0.0018077646030254524.
# reconstruction error=1.1745369822232676, variation=-0.0017857427694385475.
# reconstruction error=1.1763011771117087, variation=-0.0017641948884410397.
#
# masked_error -> 1422695.6175565424
# unmasked_error -> 9887203.232094951
# tucker - rank-3 masked_explained-> 0.9700246146916202
# tucker - rank-3 unmasked_explained-> -0.4477304509192458
# tucker - rank-3 took-> 36.1066370010376
#
# reconstruction error=0.4448750843690079, variation=-0.10645299277201958.
# reconstruction error=0.5112870498242111, variation=-0.06641196545520323.
# reconstruction error=0.55931659324812, variation=-0.04802954342390886.
# reconstruction error=0.5967907687274807, variation=-0.037474175479360716.
# reconstruction error=0.6274389557311977, variation=-0.030648187003716965.
# reconstruction error=0.6533247652088459, variation=-0.02588580947764818.
# reconstruction error=0.6757059621834139, variation=-0.022381196974568085.
# reconstruction error=0.6954034342472443, variation=-0.019697472063830324.
# reconstruction error=0.7129811843471797, variation=-0.017577750099935452.
# reconstruction error=0.7288426364581913, variation=-0.01586145211101153.
# reconstruction error=0.7432859000453848, variation=-0.0144432635871935.
# reconstruction error=0.7565372775230856, variation=-0.013251377477700887.
# reconstruction error=0.7687725065075226, variation=-0.012235228984436963.
# reconstruction error=0.7801307342304808, variation=-0.011358227722958247.
# reconstruction error=0.7907240033855738, variation=-0.010593269155092955.
# reconstruction error=0.800643867052051, variation=-0.009919863666477235.
# reconstruction error=0.8099661111605467, variation=-0.009322244108495692.
# reconstruction error=0.8187541962351363, variation=-0.008788085074589613.
# reconstruction error=0.8270618120441986, variation=-0.008307615809062252.
# reconstruction error=0.8349348049710204, variation=-0.007872992926821754.
# reconstruction error=0.8424126535208825, variation=-0.0074778485498621095.
# reconstruction error=0.8495296128432273, variation=-0.007116959322344796.
# reconstruction error=0.8563156131224109, variation=-0.006786000279183635.
# reconstruction error=0.8627969724160582, variation=-0.0064813592936473485.
# reconstruction error=0.8689969678636784, variation=-0.006199995447620177.
# reconstruction error=0.8749362975654658, variation=-0.005939329701787344.
# reconstruction error=0.8806334571940837, variation=-0.005697159628617943.
# reconstruction error=0.8861050494796219, variation=-0.005471592285538174.
# reconstruction error=0.8913660403918026, variation=-0.005260990912180685.
# reconstruction error=0.8964299726587287, variation=-0.005063932266926141.
# reconstruction error=0.9013091448844613, variation=-0.004879172225732642.
# reconstruction error=0.9060147627347166, variation=-0.00470561785025525.
# reconstruction error=0.9105570672944721, variation=-0.004542304559755461.
# reconstruction error=0.9149454446522075, variation=-0.004388377357735451.
# reconstruction error=0.919188519953203, variation=-0.004243075300995547.
# reconstruction error=0.923294238530579, variation=-0.004105718577375961.
# reconstruction error=0.9272699362253396, variation=-0.003975697694760583.
# reconstruction error=0.931122400613497, variation=-0.0038524643881574505.
# reconstruction error=0.9348579245461371, variation=-0.0037355239326400946.
# reconstruction error=0.938482353158748, variation=-0.0036244286126108083.
# reconstruction error=0.9420011253057669, variation=-0.0035187721470189004.
# reconstruction error=0.9454193102146614, variation=-0.0034181849088945615.
# reconstruction error=0.9487416400226257, variation=-0.0033223298079643193.
# reconstruction error=0.951972538752226, variation=-0.003230898729600251.
# reconstruction error=0.9551161481947461, variation=-0.0031436094425201233.
# reconstruction error=0.9581763510980963, variation=-0.0030602029033501843.
# reconstruction error=0.9611567919966166, variation=-0.0029804408985203423.
# reconstruction error=0.9640608959708691, variation=-0.0029041039742524477.
# reconstruction error=0.9668918855842042, variation=-0.0028309896133351664.
# reconstruction error=0.9696527962086708, variation=-0.002760910624466595.
# reconstruction error=0.9723464899236355, variation=-0.00269369371496464.
# reconstruction error=0.9749756681462719, variation=-0.002629178222636419.
# reconstruction error=0.9775428831321428, variation=-0.0025672149858708693.
# reconstruction error=0.9800505484666445, variation=-0.002507665334501752.
# reconstruction error=0.982500948652895, variation=-0.0024504001862504232.
# reconstruction error=0.9848962478888525, variation=-0.002395299235957604.
# reconstruction error=0.9872384981152484, variation=-0.002342250226395892.
# reconstruction error=0.9895296464064252, variation=-0.0022911482911767145.
# reconstruction error=0.9917715417678231, variation=-0.002241895361397961.
# reconstruction error=0.9939659413966935, variation=-0.0021943996288703582.
# reconstruction error=0.9961145164563279, variation=-0.0021485750596343944.
# reconstruction error=0.998218857408616, variation=-0.002104340952288175.
# reconstruction error=1.0002804789449715, variation=-0.0020616215363554735.
# reconstruction error=1.0023008245514111, variation=-0.0020203456064395997.
# reconstruction error=1.0042812707399396, variation=-0.0019804461885284397.
# reconstruction error=1.0062231309750433, variation=-0.0019418602351037872.
# reconstruction error=1.0081276593212807, variation=-0.001904528346237333.
# reconstruction error=1.0099960538353336, variation=-0.0018683945140529623.
# reconstruction error=1.0118294597236752, variation=-0.0018334058883415771.
# reconstruction error=1.0136289722849439, variation=-0.0017995125612686458.
# reconstruction error=1.0153956396543102, variation=-0.0017666673693663704.
# reconstruction error=1.0171304653655708, variation=-0.0017348257112606014.
# reconstruction error=1.018834410745196, variation=-0.0017039453796252602.
# reconstruction error=1.0205083971512963, variation=-0.0016739864061001697.
# reconstruction error=1.022153308069353, variation=-0.0016449109180567412.
# reconstruction error=1.02376999107546, variation=-0.001616683006107067.
# reconstruction error=1.0253592596769316, variation=-0.0015892686014715718.
# reconstruction error=1.026921895039242, variation=-0.0015626353623103828.
# reconstruction error=1.0284586476075874, variation=-0.0015367525683454009.
# reconstruction error=1.0299702386305638, variation=-0.0015115910229763774.
# reconstruction error=1.0314573615929206, variation=-0.0014871229623567572.
# reconstruction error=1.0329206835637366, variation=-0.0014633219708160006.
# reconstruction error=1.0343608464658476, variation=-0.0014401629021110196.
# reconstruction error=1.0357784682719604, variation=-0.0014176218061128232.
# reconstruction error=1.0371741441323512, variation=-0.0013956758603907993.
# reconstruction error=1.03854844743877, variation=-0.001374303306418856.
# reconstruction error=1.0399019308287458, variation=-0.0013534833899757626.
# reconstruction error=1.041235127134204, variation=-0.0013331963054581397.
# reconstruction error=1.0425485502780039, variation=-0.0013134231437998967.
# reconstruction error=1.0438426961217222, variation=-0.0012941458437183417.
# reconstruction error=1.0451180432678133, variation=-0.0012753471460911214.
# reconstruction error=1.0463750538189538, variation=-0.0012570105511404694.
# reconstruction error=1.0476141740972895, variation=-0.0012391202783357258.
# reconstruction error=1.0488358353260376, variation=-0.0012216612287481166.
# reconstruction error=1.0500404542757331, variation=-0.0012046189496954796.
# reconstruction error=1.0512284338772508, variation=-0.0011879796015177302.
# reconstruction error=1.052400163803623, variation=-0.0011717299263720449.
# reconstruction error=1.0535560210224708, variation=-0.0011558572188479221.
#
# masked_error -> 1138247.6515402256
# unmasked_error -> 8814971.753364915
# tucker - rank-4 masked_explained-> 0.9808126802612818
# tucker - rank-4 unmasked_explained-> -0.15075438066371008
# tucker - rank-4 took-> 37.30884146690369
#
# reconstruction error=0.4096426123175389, variation=-0.09833175765093388.
# reconstruction error=0.4707093778259059, variation=-0.06106676550836698.
# reconstruction error=0.5148166455696312, variation=-0.044107267743725365.
# reconstruction error=0.5491921108840814, variation=-0.03437546531445013.
# reconstruction error=0.577259169959049, variation=-0.02806705907496765.
# reconstruction error=0.600912560603002, variation=-0.023653390643953.
# reconstruction error=0.6213112362703568, variation=-0.02039867566735476.
# reconstruction error=0.6392152611648954, variation=-0.017904024894538573.
# reconstruction error=0.6551494493238296, variation=-0.015934188158934215.
# reconstruction error=0.6694909159259079, variation=-0.014341466602078357.
# reconstruction error=0.6825194504488932, variation=-0.013028534522985247.
# reconstruction error=0.6944481803517303, variation=-0.01192872990283711.
# reconstruction error=0.7054430964387499, variation=-0.010994916087019635.
# reconstruction error=0.7156359523811674, variation=-0.010192855942417478.
# reconstruction error=0.7251330530823745, variation=-0.009497100701207128.
# reconstruction error=0.7340214003648601, variation=-0.008888347282485554.
# reconstruction error=0.742373087999867, variation=-0.008351687635006932.
# reconstruction error=0.7502485068850423, variation=-0.00787541888517529.
# reconstruction error=0.7576987241365047, variation=-0.007450217251462443.
# reconstruction error=0.7647672790617908, variation=-0.007068554925286019.
# reconstruction error=0.7714915626597442, variation=-0.006724283597953407.
# reconstruction error=0.7779038972507903, variation=-0.006412334591046176.
# reconstruction error=0.7840323983728891, variation=-0.0061285011220987284.
# reconstruction error=0.7899016760314198, variation=-0.005869277658530736.
# reconstruction error=0.7955334136083492, variation=-0.005631737576929363.
# reconstruction error=0.8009468489679124, variation=-0.005413435359563179.
# reconstruction error=0.8061591731735084, variation=-0.005212324205596031.
# reconstruction error=0.8111858573384443, variation=-0.005026684164935902.
# reconstruction error=0.8160409164871361, variation=-0.004855059148691776.
# reconstruction error=0.8207371194287032, variation=-0.00469620294156714.
# reconstruction error=0.8252861540879831, variation=-0.004549034659279916.
# reconstruction error=0.8296987575755526, variation=-0.004412603487569444.
# reconstruction error=0.8339848192758595, variation=-0.004286061700306987.
# reconstruction error=0.8381534636584822, variation=-0.004168644382622655.
# reconstruction error=0.8422131178090891, variation=-0.0040596541506069395.
# reconstruction error=0.8461715671887334, variation=-0.003958449379644291.
# reconstruction error=0.8500360020385287, variation=-0.003864434849795262.
# reconstruction error=0.8538130561673253, variation=-0.0037770541287965864.
# reconstruction error=0.8575088395134023, variation=-0.0036957833460770084.
# reconstruction error=0.8611289657441498, variation=-0.003620126230747478.
# reconstruction error=0.8646785761400254, variation=-0.0035496103958756464.
# reconstruction error=0.8681623610119497, variation=-0.003483784871924245.
# reconstruction error=0.8715845798627007, variation=-0.003422218850751002.
# reconstruction error=0.8749490813872632, variation=-0.0033645015245625798.
# reconstruction error=0.8782593242051927, variation=-0.003310242817929465.
# reconstruction error=0.8815183989424847, variation=-0.0032590747372920337.
# reconstruction error=0.8847290519618427, variation=-0.0032106530193579674.
# reconstruction error=0.8878937107194287, variation=-0.003164658757585981.
# reconstruction error=0.8910145104447402, variation=-0.0031207997253115405.
# reconstruction error=0.8940933216321021, variation=-0.003078811187361863.
# reconstruction error=0.8971317777162261, variation=-0.0030384560841240082.
# reconstruction error=0.9001313022818492, variation=-0.002999524565623135.
# reconstruction error=0.9030931352144163, variation=-0.002961832932567021.
# reconstruction error=0.9060183573107976, variation=-0.0029252220963813524.
# reconstruction error=0.9089079130081582, variation=-0.002889555697360602.
# reconstruction error=0.9117626310304544, variation=-0.0028547180222961988.
# reconstruction error=0.9145832428773751, variation=-0.0028206118469207286.
# reconstruction error=0.917370399179963, variation=-0.0027871563025878565.
# reconstruction error=0.9201246840181508, variation=-0.002754284838187848.
# reconstruction error=0.9228466273403972, variation=-0.0027219433222464007.
# reconstruction error=0.925536715650077, variation=-0.002690088309679761.
# reconstruction error=0.9281954011325715, variation=-0.0026586854824944828.
# reconstruction error=0.9308231093967884, variation=-0.002627708264216877.
# reconstruction error=0.933420245998396, variation=-0.0025971366016076525.
# reconstruction error=0.9359872019021849, variation=-0.002566955903788859.
# reconstruction error=0.9385243580287719, variation=-0.0025371561265870035.
# reconstruction error=0.941032089017388, variation=-0.002507730988616119.
# reconstruction error=0.9435107663217837, variation=-0.00247867730439566.
# reconstruction error=0.9459607607408289, variation=-0.002449994419045254.
# reconstruction error=0.9483824444693932, variation=-0.002421683728564328.
# reconstruction error=0.9507761927387768, variation=-0.0023937482693835443.
# reconstruction error=0.9531423850999738, variation=-0.0023661923611970614.
# reconstruction error=0.9554814063876446, variation=-0.0023390212876707173.
# reconstruction error=0.9577936473883479, variation=-0.0023122410007033745.
# reconstruction error=0.9600795052239525, variation=-0.0022858578356045323.
# reconstruction error=0.9623393834504926, variation=-0.0022598782265401685.
# reconstruction error=0.9645736918645386, variation=-0.002234308414045927.
# reconstruction error=0.9667828460038492, variation=-0.002209154139310665.
# reconstruction error=0.9689672663268222, variation=-0.0021844203229729464.
# reconstruction error=0.9711273770565072, variation=-0.0021601107296850275.
# reconstruction error=0.9732636046795815, variation=-0.002136227623074305.
# reconstruction error=0.9753763760988736, variation=-0.0021127714192921143.
# reconstruction error=0.9774661164494896, variation=-0.0020897403506159318.
# reconstruction error=0.9795332466028316, variation=-0.002067130153342034.
# reconstruction error=0.9815781803992082, variation=-0.0020449337963766023.
# reconstruction error=0.9836013216672865, variation=-0.0020231412680783434.
# reconstruction error=0.9856030611059517, variation=-0.0020017394386652176.
# reconstruction error=0.9875837731200181, variation=-0.0019807120140663548.
# reconstruction error=0.9895438127138162, variation=-0.001960039593798091.
# reconstruction error=0.9914835125547272, variation=-0.0019396998409110244.
# reconstruction error=0.9934031803208163, variation=-0.0019196677660890948.
# reconstruction error=0.9953030964421031, variation=-0.0018999161212868154.
# reconstruction error=0.997183512333328, variation=-0.0018804158912248958.
# reconstruction error=0.9990446491978783, variation=-0.0018611368645502502.
# reconstruction error=1.0008866974589348, variation=-0.0018420482610564948.
# reconstruction error=1.0027098168463655, variation=-0.0018231193874307383.
# reconstruction error=1.0045141371388704, variation=-0.0018043202925048796.
# reconstruction error=1.0062997595322867, variation=-0.0017856223934162863.
#
# masked_error -> 999771.3916457321
# unmasked_error -> 8403267.768706646
# tucker - rank-5 masked_explained-> 0.9851972570570896
# tucker - rank-5 unmasked_explained-> -0.04577243869315375
# tucker - rank-5 took-> 37.92412447929382
#
# reconstruction error=0.40441823878034194, variation=-0.09484607693476077.
# reconstruction error=0.4639565438669936, variation=-0.059538305086651644.
# reconstruction error=0.5074341809132636, variation=-0.04347763704627006.
# reconstruction error=0.5417172265911036, variation=-0.03428304567783991.
# reconstruction error=0.5700351150030231, variation=-0.028317888411919512.
# reconstruction error=0.5941549883131567, variation=-0.024119873310133655.
# reconstruction error=0.6151446817038341, variation=-0.020989693390677355.
# reconstruction error=0.6336981579968415, variation=-0.01855347629300741.
# reconstruction error=0.6502932433638748, variation=-0.016595085367033358.
# reconstruction error=0.6652750558829552, variation=-0.014981812519080373.
# reconstruction error=0.6789029534930751, variation=-0.013627897610119843.
# reconstruction error=0.6913782333572087, variation=-0.01247527986413366.
# reconstruction error=0.7028611602996552, variation=-0.011482926942446459.
# reconstruction error=0.7134818748529533, variation=-0.01062071455329816.
# reconstruction error=0.7233476867990689, variation=-0.009865811946115577.
# reconstruction error=0.7325481603461159, variation=-0.009200473547047006.
# reconstruction error=0.7411587936710553, variation=-0.008610633324939387.
# reconstruction error=0.7492437637477424, variation=-0.00808497007668707.
# reconstruction error=0.7568580235475069, variation=-0.007614259799764489.
# reconstruction error=0.764048934552208, variation=-0.00719091100470115.
# reconstruction error=0.7708575563554413, variation=-0.006808621803233272.
# reconstruction error=0.7773196775987844, variation=-0.006462121243343111.
# reconstruction error=0.783466648403158, variation=-0.006146970804373653.
# reconstruction error=0.7893260583453207, variation=-0.005859409942162608.
# reconstruction error=0.7949222928723599, variation=-0.005596234527039279.
# reconstruction error=0.8002769931008816, variation=-0.005354700228521692.
# reconstruction error=0.8054094381627606, variation=-0.005132445061878932.
# reconstruction error=0.8103368649747271, variation=-0.004927426811966562.
# reconstruction error=0.8150747370916507, variation=-0.004737872116923558.
# reconstruction error=0.8196369718595357, variation=-0.004562234767884976.
# reconstruction error=0.8240361332094613, variation=-0.004399161349925684.
# reconstruction error=0.8282835959827304, variation=-0.0042474627732690395.
# reconstruction error=0.8323896865451975, variation=-0.004106090562467135.
# reconstruction error=0.8363638035583549, variation=-0.003974117013157419.
# reconstruction error=0.8402145220693904, variation=-0.003850718511035467.
# reconstruction error=0.8439496835199761, variation=-0.0037351614505857222.
# reconstruction error=0.8475764738219863, variation=-0.0036267903020101855.
# reconstruction error=0.8511014912839588, variation=-0.003525017461972535.
# reconstruction error=0.8545308058762111, variation=-0.003429314592252264.
# reconstruction error=0.857870011081378, variation=-0.0033392052051668397.
# reconstruction error=0.8611242693795045, variation=-0.0032542582981265333.
# reconstruction error=0.8642983522543448, variation=-0.003174082874840334.
# reconstruction error=0.8673966754733219, variation=-0.0030983232189770726.
# reconstruction error=0.8704233302824064, variation=-0.0030266548090844836.
# reconstruction error=0.8733821110645505, variation=-0.002958780782144177.
# reconstruction error=0.8762765399329591, variation=-0.002894428868408516.
# reconstruction error=0.8791098886653421, variation=-0.0028333487323830564.
# reconstruction error=0.8818851983304117, variation=-0.0027753096650695586.
# reconstruction error=0.8846052969110144, variation=-0.0027200985806027367.
# reconstruction error=0.8872728151882692, variation=-0.0026675182772547545.
# reconstruction error=0.8898902011164063, variation=-0.002617385928137095.
# reconstruction error=0.892459732887898, variation=-0.002569531771491773.
# reconstruction error=0.8949835308619907, variation=-0.002523797974092634.
# reconstruction error=0.8974635685063492, variation=-0.002480037644358557.
# reconstruction error=0.8999016824807885, variation=-0.002438113974439271.
# reconstruction error=0.902299581973429, variation=-0.002397899492640465.
# reconstruction error=0.9046588573831257, variation=-0.002359275409696715.
# reconstruction error=0.9069809884271436, variation=-0.0023221310440179055.
# reconstruction error=0.909267351739971, variation=-0.0022863633128273886.
# reconstruction error=0.9115192280175538, variation=-0.0022518762775828316.
# reconstruction error=0.9137378087511072, variation=-0.0022185807335534102.
# reconstruction error=0.9159242025860396, variation=-0.002186393834932354.
# reconstruction error=0.9180794413341208, variation=-0.002155238748081212.
# reconstruction error=0.9202044856610538, variation=-0.0021250443269330566.
# reconstruction error=0.9223002304667078, variation=-0.0020957448056539985.
# reconstruction error=0.9243675099715442, variation=-0.002067279504836317.
# reconstruction error=0.9264071025199527, variation=-0.0020395925484085753.
# reconstruction error=0.9284197351093125, variation=-0.0020126325893597974.
# reconstruction error=0.9304060876523657, variation=-0.001986352543053127.
# reconstruction error=0.9323667969798239, variation=-0.0019607093274582876.
# reconstruction error=0.93430246059, variation=-0.0019356636101760527.
# reconstruction error=0.9362136401523486, variation=-0.0019111795623486527.
# reconstruction error=0.938100864772172, variation=-0.00188722461982338.
# reconstruction error=0.9399646340243065, variation=-0.001863769252134495.
# reconstruction error=0.9418054207640238, variation=-0.001840786739717326.
# reconstruction error=0.9436236737240747, variation=-0.0018182529600508923.
# reconstruction error=0.9454198199071358, variation=-0.0017961461830610093.
# reconstruction error=0.9471942667834681, variation=-0.0017744468763323251.
# reconstruction error=0.9489474043037858, variation=-0.0017531375203176935.
# reconstruction error=0.9506796067376372, variation=-0.0017322024338514153.
# reconstruction error=0.9523912343476081, variation=-0.0017116276099709005.
# reconstruction error=0.95408263490972, variation=-0.0016914005621119221.
# reconstruction error=0.955754145090278, variation=-0.0016715101805580002.
# reconstruction error=0.9574060916892138, variation=-0.0016519465989357496.
# reconstruction error=0.9590387927597576, variation=-0.0016327010705438072.
# reconstruction error=0.9606525586139193, variation=-0.0016137658541617306.
# reconstruction error=0.9622476927229209, variation=-0.0015951341090015836.
# reconstruction error=0.9638244925212712, variation=-0.001576799798350348.
# reconstruction error=0.9653832501227364, variation=-0.0015587576014651772.
# reconstruction error=0.9669242529560188, variation=-0.001541002833282401.
# reconstruction error=0.9684477843273693, variation=-0.0015235313713505283.
# reconstruction error=0.9699541239169166, variation=-0.0015063395895472675.
# reconstruction error=0.9714435482149333, variation=-0.0014894242980166839.
# reconstruction error=0.972916330903729, variation=-0.001472782688795693.
# reconstruction error=0.9743727431903134, variation=-0.0014564122865844409.
# reconstruction error=0.9758130540944571, variation=-0.001440310904143649.
# reconstruction error=0.9772375306962414, variation=-0.0014244766017843524.
# reconstruction error=0.9786464383466905, variation=-0.0014089076504490983.
#
# masked_error -> 913686.9399488105
# unmasked_error -> 8156210.916059523
# tucker - rank-6 masked_explained-> 0.9876366654502616
# tucker - rank-6 unmasked_explained-> 0.014815245328251741
# tucker - rank-6 took-> 38.856027126312256
#
# reconstruction error=0.39004446935660475, variation=-0.0896472918724871.
# reconstruction error=0.4460819461448015, variation=-0.05603747678819676.
# reconstruction error=0.4869241172508922, variation=-0.040842171106090674.
# reconstruction error=0.519115064809626, variation=-0.03219094755873381.
# reconstruction error=0.5457146663121276, variation=-0.026599601502501624.
# reconstruction error=0.5683937246764273, variation=-0.02267905836429973.
# reconstruction error=0.5881646386036539, variation=-0.01977091392722652.
# reconstruction error=0.6056888767267393, variation=-0.017524238123085456.
# reconstruction error=0.621424056613822, variation=-0.01573517988708273.
# reconstruction error=0.6357012619121523, variation=-0.014277205298330209.
# reconstruction error=0.6487686770331231, variation=-0.013067415120970871.
# reconstruction error=0.6608175705404521, variation=-0.012048893507328962.
# reconstruction error=0.6719984284406588, variation=-0.011180857900206731.
# reconstruction error=0.6824313495378389, variation=-0.010432921097180081.
# reconstruction error=0.6922130329569569, variation=-0.009781683419118004.
# reconstruction error=0.7014217515544799, variation=-0.009208718597523036.
# reconstruction error=0.7101211471566252, variation=-0.008699395602145277.
# reconstruction error=0.718363303465434, variation=-0.008242156308808757.
# reconstruction error=0.7261912905608047, variation=-0.007827987095370692.
# reconstruction error=0.7336412320953819, variation=-0.007449941534577231.
# reconstruction error=0.7407439139033645, variation=-0.007102681807982569.
# reconstruction error=0.7475259839067455, variation=-0.006782070003381047.
# reconstruction error=0.7540108281930433, variation=-0.006484844286297808.
# reconstruction error=0.7602192142995742, variation=-0.00620838610653085.
# reconstruction error=0.7661697736319633, variation=-0.005950559332389083.
# reconstruction error=0.7718793695746047, variation=-0.005709595942641421.
# reconstruction error=0.7773633794691961, variation=-0.005484009894591413.
# reconstruction error=0.782635909421414, variation=-0.005272529952217941.
# reconstruction error=0.7877099572000776, variation=-0.005074047778663604.
# reconstruction error=0.7925975365209709, variation=-0.004887579320893232.
# reconstruction error=0.7973097739210699, variation=-0.004712237400099073.
# reconstruction error=0.8018569869686745, variation=-0.004547213047604526.
# reconstruction error=0.8062487500827371, variation=-0.004391763114062641.
# reconstruction error=0.8104939521139061, variation=-0.00424520203116896.
# reconstruction error=0.8146008482367549, variation=-0.004106896122848869.
# reconstruction error=0.8185771076103168, variation=-0.00397625937356183.
# reconstruction error=0.8224298575859219, variation=-0.003852749975605141.
# reconstruction error=0.8261657248585047, variation=-0.0037358672725827935.
# reconstruction error=0.8297908737654838, variation=-0.00362514890697907.
# reconstruction error=0.8333110418573773, variation=-0.003520168091893483.
# reconstruction error=0.836731572843945, variation=-0.0034205309865676936.
# reconstruction error=0.8400574470262072, variation=-0.0033258741822622673.
# reconstruction error=0.8432933093400106, variation=-0.0032358623138033504.
# reconstruction error=0.8464434951515093, variation=-0.003150185811498729.
# reconstruction error=0.8495120539551, variation=-0.003068558803590693.
# reconstruction error=0.8525027711288801, variation=-0.0029907171737800775.
# reconstruction error=0.8554191879022917, variation=-0.0029164167734115898.
# reconstruction error=0.8582646196859498, variation=-0.0028454317836581478.
# reconstruction error=0.861042172906049, variation=-0.002777553220099205.
# reconstruction error=0.8637547604764048, variation=-0.002712587570355751.
# reconstruction error=0.8664051160305988, variation=-0.002650355554194017.
# reconstruction error=0.8689958070258893, variation=-0.0025906909952905233.
# reconstruction error=0.8715292468198471, variation=-0.0025334397939578146.
# ...
# reconstruction error=0.9144613335731497, variation=-0.0012136186227108547.
# reconstruction error=0.915656042124275, variation=-0.0011947085511252453.
# reconstruction error=0.9168323152198329, variation=-0.0011762730955579004.
# reconstruction error=0.9179906138167594, variation=-0.0011582985969265103.
# reconstruction error=0.9191313856496933, variation=-0.001140771832933929.
# reconstruction error=0.9202550656517119, variation=-0.0011236800020185678.
# reconstruction error=0.9213620763598228, variation=-0.0011070107081109226.
# reconstruction error=0.9224528283059217, variation=-0.0010907519460988668.
# reconstruction error=0.9235277203939145, variation=-0.0010748920879928292.
# reconstruction error=0.9245871402635641, variation=-0.001059419869649636.
#
# masked_error -> 802911.5872911809
# unmasked_error -> 7690460.889101905
# tucker - rank-8 masked_explained-> 0.9904527952208898
# tucker - rank-8 unmasked_explained-> 0.12411815900789851
# tucker - rank-8 took-> 42.17727327346802
#
# reconstruction error=0.3823386361623592, variation=-0.0852929115847581.
# reconstruction error=0.4355612810813571, variation=-0.05322264491899792.
# reconstruction error=0.47411551708630534, variation=-0.03855423600494823.
# reconstruction error=0.5042967475388515, variation=-0.030181230452546115.
# reconstruction error=0.5290881580594647, variation=-0.02479141052061329.
# reconstruction error=0.5501352463266167, variation=-0.02104708826715196.
# reconstruction error=0.5684407623373761, variation=-0.01830551601075936.
# reconstruction error=0.5846595867379446, variation=-0.016218824400568543.
# reconstruction error=0.5992410702697066, variation=-0.01458148353176203.
# reconstruction error=0.612504767821453, variation=-0.01326369755174639.
# reconstruction error=0.6246840162653403, variation=-0.012179248443887292.
# reconstruction error=0.6359527567234788, variation=-0.011268740458138526.
# reconstruction error=0.6464430571226985, variation=-0.01049030039921961.
# reconstruction error=0.6562571146286983, variation=-0.00981405750599984.
# reconstruction error=0.6654756997052369, variation=-0.00921858507653861.
# reconstruction error=0.6741641154322225, variation=-0.008688415726985643.
# reconstruction error=0.682376349136428, variation=-0.00821223370420543.
# reconstruction error=0.69015792198527, variation=-0.007781572848842067.
# reconstruction error=0.6975478382939021, variation=-0.007389916308632061.
# reconstruction error=0.7045799384817791, variation=-0.007032100187877033.
# reconstruction error=0.711283866089612, variation=-0.0067039276078328935.
# reconstruction error=0.7176857836278294, variation=-0.006401917538217394.
# reconstruction error=0.7238089200747037, variation=-0.006123136446874233.
# reconstruction error=0.7296740010456162, variation=-0.0058650809709125395.
# reconstruction error=0.7352995942196908, variation=-0.005625593174074628.
# reconstruction error=0.7407023918193671, variation=-0.005402797599676323.
# reconstruction error=0.7458974452722701, variation=-0.005195053452902942.
# reconstruction error=0.7508983628154644, variation=-0.0050009175431943165.
# reconstruction error=0.7557174778374609, variation=-0.004819115021996501.
# reconstruction error=0.7603659937234257, variation=-0.004648515885964821.
# reconstruction error=0.7648541095753537, variation=-0.004488115851927987.
# reconstruction error=0.7691911302010096, variation=-0.004337020625655885.
# reconstruction error=0.7733855630376487, variation=-0.004194432836639117.
# reconstruction error=0.7774452040910865, variation=-0.0040596410534378125.
# reconstruction error=0.7813772144749044, variation=-0.003932010383817852.
# reconstruction error=0.7851881887201599, variation=-0.0038109742452555606.
# reconstruction error=0.7888842157056453, variation=-0.0036960269854853234.
# reconstruction error=0.7924709328436746, variation=-0.0035867171380293827.
# reconstruction error=0.7959535740415608, variation=-0.003482641197886105.
# reconstruction error=0.7993370119225891, variation=-0.0033834378810283505.
# reconstruction error=0.8026257947995622, variation=-0.0032887828769730953.
# reconstruction error=0.8058241789183083, variation=-0.003198384118746067.
# reconstruction error=0.808936156504441, variation=-0.003111977586132686.
# reconstruction error=0.8119654801426993, variation=-0.0030293236382583633.
# reconstruction error=0.8149156839926696, variation=-0.0029502038499702454.
# reconstruction error=0.8177901023018127, variation=-0.0028744183091431452.
# reconstruction error=0.8205918856238172, variation=-0.0028017833220045363.
# reconstruction error=0.8233240150940115, variation=-0.0027321294701943.
# reconstruction error=0.8259893150592998, variation=-0.0026652999652883036.
# reconstruction error=0.8285904643110381, variation=-0.002601149251738266.
# reconstruction error=0.8311300061268593, variation=-0.002539541815821167.
# reconstruction error=0.8336103572920454, variation=-0.002480351165186079.
# reconstruction error=0.8360338162418323, variation=-0.0024234589497869052.
# reconstruction error=0.8384025704424621, variation=-0.0023687542006298745.
# reconstruction error=0.8407187031095572, variation=-0.002316132667095072.
# reconstruction error=0.8429841993468972, variation=-0.002265496237339959.
# reconstruction error=0.8452009517759088, variation=-0.002216752429011648.
# reconstruction error=0.8473707657157836, variation=-0.0021698139398748095.
# reconstruction error=0.8494953639654226, variation=-0.0021245982496389537.
# reconstruction error=0.8515763912311369, variation=-0.0020810272657143525.
# reconstruction error=0.8536154182379825, variation=-0.0020390270068455507.
# reconstruction error=0.8556139455574028, variation=-0.0019985273194202957.
# reconstruction error=0.8575734071794753, variation=-0.0019594616220725003.
# reconstruction error=0.8594951738543752, variation=-0.0019217666748999607.
# reconstruction error=0.8613805562244463, variation=-0.001885382370071076.
# reconstruction error=0.8632308077656216, variation=-0.0018502515411752407.
# reconstruction error=0.865047127554573, variation=-0.0018163197889514704.
# reconstruction error=0.8668306628760629, variation=-0.001783535321489893.
# reconstruction error=0.8685825116832424, variation=-0.0017518488071794902.
# reconstruction error=0.8703037249222172, variation=-0.0017212132389747836.
# reconstruction error=0.8719953087309673, variation=-0.001691583808750119.
# reconstruction error=0.873658226521661, variation=-0.0016629177906937187.
# reconstruction error=0.8752934009544382, variation=-0.0016351744327771645.
# reconstruction error=0.8769017158100125, variation=-0.0016083148555743332.
# reconstruction error=0.8784840177677006, variation=-0.0015823019576880482.
# reconstruction error=0.8800411180948984, variation=-0.0015571003271978023.
# reconstruction error=0.8815737942535182, variation=-0.00153267615861985.
# reconstruction error=0.8830827914283959, variation=-0.0015089971748776243.
# reconstruction error=0.8845688239822883, variation=-0.001486032553892458.
# reconstruction error=0.8860325768417114, variation=-0.0014637528594231286.
# reconstruction error=0.8874747068175193, variation=-0.0014421299758078376.
# reconstruction error=0.8888958438638526, variation=-0.0014211370463332873.
# reconstruction error=0.8902965922787918, variation=-0.0014007484149392013.
# reconstruction error=0.8916775318498219, variation=-0.0013809395710301375.
# reconstruction error=0.8930392189469866, variation=-0.0013616870971646655.
# reconstruction error=0.8943821875663954, variation=-0.0013429686194088575.
# reconstruction error=0.8957069503266051, variation=-0.0013247627602096523.
# reconstruction error=0.8970139994201554, variation=-0.0013070490935502832.
# reconstruction error=0.8983038075224653, variation=-0.0012898081023099417.
# reconstruction error=0.8995768286600888, variation=-0.001273021137623509.
# reconstruction error=0.9008334990402448, variation=-0.0012566703801559775.
# reconstruction error=0.9020742378433895, variation=-0.0012407388031446809.
# reconstruction error=0.9032994479804977, variation=-0.0012252101371081903.
# reconstruction error=0.9045095168166539, variation=-0.001210068836156264.
# reconstruction error=0.9057048168623967, variation=-0.0011953000457427532.
# reconstruction error=0.9068857064342575, variation=-0.0011808895718607992.
# reconstruction error=0.9080525302857837, variation=-0.001166823851526222.
# reconstruction error=0.9092056202103371, variation=-0.0011530899245534298.
#
# masked_error -> 772734.9469732342
# unmasked_error -> 7559955.2566936435
# tucker - rank-9 masked_explained-> 0.9911569537950771
# tucker - rank-9 unmasked_explained-> 0.15359301806258555
# tucker - rank-9 took-> 42.09245753288269
#
# reconstruction error=0.3800997586143949, variation=-0.08408267475063935.
# reconstruction error=0.4327251427100374, variation=-0.05262538409564255.
# reconstruction error=0.47084443073668614, variation=-0.03811928802664871.
# reconstruction error=0.5006421765085171, variation=-0.02979774577183092.
# reconstruction error=0.5250674812080126, variation=-0.024425304699495554.
# reconstruction error=0.54575286136062, variation=-0.020685380152607347.
# reconstruction error=0.5636945255121008, variation=-0.017941664151480796.
# reconstruction error=0.579543442634457, variation=-0.015848917122356254.
# reconstruction error=0.5937468373047464, variation=-0.014203394670289415.
# reconstruction error=0.606623775836143, variation=-0.012876938531396598.
# reconstruction error=0.6184086341171634, variation=-0.011784858281020383.
# reconstruction error=0.6292776567094771, variation=-0.010869022592313704.
# reconstruction error=0.6393660361834405, variation=-0.01008837947396335.
# reconstruction error=0.6487793662092451, variation=-0.00941333002580469.
# reconstruction error=0.6576015639139603, variation=-0.008822197704715151.
# reconstruction error=0.6659004593143467, variation=-0.008298895400386419.
# reconstruction error=0.6737317824855265, variation=-0.007831323171179738.
# reconstruction error=0.6811420274017322, variation=-0.007410244916205788.
# reconstruction error=0.6881705237021832, variation=-0.007028496300450993.
# reconstruction error=0.6948509504796078, variation=-0.006680426777424531.
# reconstruction error=0.7012124571063375, variation=-0.00636150662672974.
# reconstruction error=0.7072805061704118, variation=-0.006068049064074321.
# reconstruction error=0.7130775181311962, variation=-0.005797011960784415.
# reconstruction error=0.718623372691922, variation=-0.00554585456072576.
# reconstruction error=0.723935805045521, variation=-0.005312432353599017.
# reconstruction error=0.7290307236776816, variation=-0.0050949186321606055.
# reconstruction error=0.7339224685885746, variation=-0.004891744910892948.
# reconstruction error=0.738624023447351, variation=-0.0047015548587764355.
# reconstruction error=0.7431471915273515, variation=-0.004523168080000528.
# reconstruction error=0.7475027427429429, variation=-0.004355551215591391.
# reconstruction error=0.7517005373495615, variation=-0.004197794606618621.
# reconstruction error=0.7557496306224473, variation=-0.004049093272885718.
# reconstruction error=0.7596583619250848, variation=-0.00390873130263758.
# reconstruction error=0.7634344309027262, variation=-0.003776068977641378.
# reconstruction error=0.7670849630161282, variation=-0.0036505321134019386.
# reconstruction error=0.7706165662200403, variation=-0.0035316032039121037.
# reconstruction error=0.7740353802604641, variation=-0.0034188140404238787.
# reconstruction error=0.7773471197957302, variation=-0.0033117395352660894.
# reconstruction error=0.7805571123265236, variation=-0.0032099925307933486.
# reconstruction error=0.7836703317400745, variation=-0.003113219413550916.
# reconstruction error=0.7866914281270645, variation=-0.0030210963869899965.
# reconstruction error=0.7896247544106398, variation=-0.0029333262835753438.
# reconstruction error=0.7924743902306537, variation=-0.0028496358200138516.
# reconstruction error=0.7952441634487085, variation=-0.0027697732180548273.
# reconstruction error=0.7979376695773451, variation=-0.0026935061286366135.
# reconstruction error=0.8005582893867809, variation=-0.0026206198094357314.
# reconstruction error=0.8031092049025154, variation=-0.0025509155157344976.
# reconstruction error=0.8055934139748918, variation=-0.002484209072376453.
# reconstruction error=0.8080137435755387, variation=-0.0024203296006468644.
# reconstruction error=0.8103728619543727, variation=-0.0023591183788340686.
# reconstruction error=0.81267328977329, variation=-0.002300427818917261.
# reconstruction error=0.8149174103180855, variation=-0.0022441205447955026.
# reconstruction error=0.8171074788778784, variation=-0.002190068559792868.
# reconstruction error=0.8192456313708627, variation=-0.0021381524929843243.
# reconstruction error=0.8213338922861415, variation=-0.0020882609152788056.
# reconstruction error=0.8233741820036601, variation=-0.002040289717518573.
# reconstruction error=0.8253683235473718, variation=-0.0019941415437116916.
# reconstruction error=0.8273180488207649, variation=-0.0019497252733930992.
# reconstruction error=0.8292250043687722, variation=-0.0019069555480073497.
# reconstruction error=0.8310907567054111, variation=-0.0018657523366388817.
# reconstruction error=0.8329167972427277, variation=-0.0018260405373166089.
# reconstruction error=0.834704546853165, variation=-0.0017877496104372614.
# reconstruction error=0.8364553600946811, variation=-0.0017508132415161581.
# reconstruction error=0.8381705291255066, variation=-0.0017151690308254697.
# reconstruction error=0.8398512873333376, variation=-0.001680758207830979.
# reconstruction error=0.8414988127019383, variation=-0.0016475253686006885.
# reconstruction error=0.8431142309365547, variation=-0.001615418234616417.
# reconstruction error=0.8446986183679603, variation=-0.0015843874314056539.
# reconstruction error=0.8462530046536142, variation=-0.0015543862856538526.
# reconstruction error=0.8477783752929617, variation=-0.0015253706393475452.
# reconstruction error=0.8492756739726259, variation=-0.001497298679664194.
# reconstruction error=0.8507458047558434, variation=-0.0014701307832174493.
# reconstruction error=0.8521896341292575, variation=-0.0014438293734141405.
# reconstruction error=0.8536079929189129, variation=-0.0014183587896553496.
# reconstruction error=0.8550016780861629, variation=-0.001393685167250025.
# reconstruction error=0.8563714544130906, variation=-0.0013697763269276964.
# reconstruction error=0.8577180560860652, variation=-0.0013466016729746233.
# reconstruction error=0.8590421881852097, variation=-0.0013241320991445038.
# reconstruction error=0.8603445280867147, variation=-0.0013023399015049675.
# reconstruction error=0.8616257267843418, variation=-0.0012811986976271061.
# reconstruction error=0.8628864101357541, variation=-0.0012606833514122728.
# reconstruction error=0.8641271800388929, variation=-0.0012407699031388164.
# reconstruction error=0.8653486155431322, variation=-0.0012214355042393654.
# reconstruction error=0.8665512738995265, variation=-0.001202658356394215.
# reconstruction error=0.86773569155416, variation=-0.0011844176546335072.
# reconstruction error=0.8689023850882656, variation=-0.0011666935341055895.
# reconstruction error=0.8700518521085036, variation=-0.001149467020237993.
# reconstruction error=0.8711845720905482, variation=-0.001132719982044672.
# reconstruction error=0.8723010071788554, variation=-0.001116435088307166.
# reconstruction error=0.8734016029453504, variation=-0.0011005957664950161.
# reconstruction error=0.8744867891094652, variation=-0.001085186164114793.
# reconstruction error=0.8755569802218525, variation=-0.0010701911123872643.
# reconstruction error=0.8766125763139014, variation=-0.0010555960920489715.
# reconstruction error=0.8776539635150555, variation=-0.001041387201154098.
# reconstruction error=0.8786815146397108, variation=-0.001027551124655246.
# reconstruction error=0.8796955897454583, variation=-0.0010140751057474695.
# reconstruction error=0.88069653666421, variation=-0.001000946918751744.
# reconstruction error=0.8816846915077027, variation=-0.0009881548434926835.
#
# masked_error -> 757615.0769908268
# unmasked_error -> 7331778.604295672
# tucker - rank-10 masked_explained-> 0.9914996265831784
# tucker - rank-10 unmasked_explained-> 0.20391494434588325
# tucker - rank-10 took-> 44.08993148803711

# %%
# Lets now build the matrix with shape  (nodes ^ 2) x  t 
print(nptensor.shape)
npmatrix =  np.zeros((nptensor.shape[0] * nptensor.shape[1],nptensor.shape[2]))
print(npmatrix.shape)

for x in range(npmatrix.shape[1]):
    npmatrix[:,x] = nptensor[:,:,x].flatten()
    
    

### SVD for this matrix

def matrixrank2variance(k):
    now = time.time()
    _svd = sklearn.decomposition.TruncatedSVD(n_components=k, n_iter=100, random_state=42)
    _svd.fit(npmatrix)
    _nparams = sum(npmatrix.shape)*k + k
    #print(svd.explained_variance_ratio_)
    took = time.time() - now
    print()
    print(f'SVD-rank-{k} explains->',_svd.explained_variance_ratio_.sum())
    print(f'SVD-rank-{k} took->',took)
    print()
    return _svd.explained_variance_ratio_.sum(), took, _nparams
# Out:
# (695, 695, 24)
# (483025, 24)

# %%
explained_svd = [matrixrank2variance(k) for k in range(1,11)]
# Out:
# SVD-rank-1 explains-> 0.8007682250150465
# SVD-rank-1 took-> 19.388776779174805
#
#
# SVD-rank-2 explains-> 0.8399175718190734
# SVD-rank-2 took-> 22.799020767211914
#
#
# SVD-rank-3 explains-> 0.8732156209306673
# SVD-rank-3 took-> 24.43186044692993
#
#
# SVD-rank-4 explains-> 0.886881152912973
# SVD-rank-4 took-> 26.576675415039062
#
#
# SVD-rank-5 explains-> 0.8981679056843997
# SVD-rank-5 took-> 29.421982288360596
#
#
# SVD-rank-6 explains-> 0.9070683748033165
# SVD-rank-6 took-> 29.19511318206787
#
#
# SVD-rank-7 explains-> 0.9154527955817334
# SVD-rank-7 took-> 30.370058298110962
#
#
# SVD-rank-8 explains-> 0.9231756907216467
# SVD-rank-8 took-> 32.47257852554321
#
#
# SVD-rank-9 explains-> 0.9304854674460095
# SVD-rank-9 took-> 34.174378395080566
#
#
# SVD-rank-10 explains-> 0.9368968167880641
# SVD-rank-10 took-> 34.505500078201294

# %%
for k in range(11,15):
    explained_svd.append(matrixrank2variance(k))
# Out:
# SVD-rank-11 explains-> 0.9429270546727646
# SVD-rank-11 took-> 38.23057150840759
#
#
# SVD-rank-12 explains-> 0.9486673526439515
# SVD-rank-12 took-> 38.545838356018066
#
#
# SVD-rank-13 explains-> 0.9540864350627989
# SVD-rank-13 took-> 38.568230390548706
#
#
# SVD-rank-14 explains-> 0.9591484220319595
# SVD-rank-14 took-> 45.924192667007446

# %%
for k in range(15,21):
    explained_svd.append(matrixrank2variance(k))
# Out:
# SVD-rank-15 explains-> 0.96416158858772
# SVD-rank-15 took-> 50.24852538108826
#
#
# SVD-rank-16 explains-> 0.9690825701947687
# SVD-rank-16 took-> 46.11126518249512
#
#
# SVD-rank-17 explains-> 0.9738820450375005
# SVD-rank-17 took-> 45.706488847732544
#
#
# SVD-rank-18 explains-> 0.9784929674354239
# SVD-rank-18 took-> 46.56642413139343
#
#
# SVD-rank-19 explains-> 0.9829818165992423
# SVD-rank-19 took-> 47.39127016067505
#
#
# SVD-rank-20 explains-> 0.9871333908179637
# SVD-rank-20 took-> 46.838913679122925

# %%
import dill
#dill.dump_session('var2rank.pickle')
#dill.load_session('var2rank_masked.pickle')

# %%
var_cp = map(lambda x:x[0], explained_parafac)
var_cportho = map(lambda x:x[0], explained_parafacortho)
var_tucker = map(lambda x:x[0], explained_tucker)
var_svd = map(lambda x:x[0], explained_svd)

took_cp = map(lambda x:x[1], explained_parafac)
took_cportho = map(lambda x:x[1], explained_parafacortho)
took_tucker = map(lambda x:x[1], explained_tucker)
took_svd = map(lambda x:x[1], explained_svd)

nparams_cp = map(lambda x:x[2], explained_parafac)
nparams_cportho = map(lambda x:x[2], explained_parafacortho)
nparams_tucker = map(lambda x:x[2], explained_tucker)
nparams_svd = map(lambda x:x[2], explained_svd)

# %%
var_cp = list(var_cp) + [None]*10
var_cportho = list(var_cportho) + [None]*10
var_tucker = list(var_tucker) + [None]*10

took_cp = list(took_cp) + [None]*10
took_cportho = list(took_cportho) + [None]*10
took_tucker = list(took_tucker) + [None]*10

nparams_cp = list(nparams_cp) + [None]*10
nparams_cportho = list(nparams_cportho) + [None]*10
nparams_tucker = list(nparams_tucker) + [None]*10

# %%
rank2var = pd.DataFrame(      {'cp': var_cp  , 'cportho': var_cportho, 'tucker': var_tucker , 'svd': var_svd}                 )
rank2var.index = range(1,21)

rank2took = pd.DataFrame(     {'cp': took_cp , 'cportho': took_cportho , 'tucker': took_tucker, 'svd': took_svd  }             )
rank2took.index = range(1,21)

rank2nparams = pd.DataFrame(   {'cp': nparams_cp  , 'cportho': nparams_cportho , 'tucker': nparams_tucker, 'svd': nparams_svd  }   )
rank2nparams.index = range(1,21)

# %%
sns.lineplot( data = rank2var.cp, color='g', label='cp' )
sns.lineplot( data = rank2var.cportho, color='r', label='cportho')
sns.lineplot( data = rank2var.tucker, color='b', label='tucker')
ax = sns.lineplot( data = rank2var.svd, color='black', label='svd')
ax.set(xlabel='rank', ylabel='explained_variance')
# Out:
# [Text(0.5, 0, 'rank'), Text(0, 0.5, 'explained_variance')]

# %%
sns.lineplot( data = rank2took.cp, color='g', label='cp')
sns.lineplot( data = rank2took.cportho, color='r', label='cportho')
sns.lineplot( data = rank2took.tucker, color='b', label='tucker')
ax = sns.lineplot( data = rank2took.svd, color='black', label='svd')
ax.set(xlabel='rank', ylabel='compute_time [seconds]')
# Out:
# [Text(0.5, 0, 'rank'), Text(0, 0.5, 'compute_time [seconds]')]

# %%
sns.lineplot( data = rank2nparams.cp, color='g', label='cp')
sns.lineplot( data = rank2nparams.cportho, color='r', label='cportho')
ax = sns.lineplot( data = rank2nparams.tucker, color='b', label='tucker')
ax = sns.lineplot( data = rank2nparams.svd, color='black', label='svd')
ax.set(xlabel='rank',ylabel='no_of_params')
ax.legend()

# %%
plt.plot(rank2var.cp, rank2took.cp, label='cp', c='g')
plt.plot(rank2var.cportho, rank2took.cportho, label='cportho', c='r')
plt.plot(rank2var.tucker, rank2took.tucker, label='tucker', c='b')
plt.plot(rank2var.svd, rank2took.svd, label='svd', c='black')
plt.xlabel('explained_variance')
plt.ylabel('compute_time_taken [second]')
plt.legend()

# %%
plt.plot(rank2var.cp, rank2nparams.cp, label='cp', c='g')
plt.plot(rank2var.cportho, rank2nparams.cportho, label='cportho', c='r')
plt.plot(rank2var.tucker, rank2nparams.tucker, label='tucker', c='b')
#plt.plot(rank2var.svd, rank2nparams.svd, label='svd', c='black')
plt.xlabel('explained_variance')
plt.ylabel('no_of_params')
plt.legend()

# %%
plt.plot(rank2var.cp *100 / rank2nparams.cp, label='cp', c='g')
plt.plot(rank2var.cportho *100/ rank2nparams.cportho, label='cportho', c='r')
plt.plot(rank2var.tucker *100/ rank2nparams.tucker, label='tucker', c='b')
plt.plot(rank2var.svd *100/ rank2nparams.svd, label='svd', c='black')
plt.xlabel('rank')
plt.ylabel('% variance_explained /  parameter ')
plt.legend()

# %%
np.array([1,2,3]) / np.array([1,2,6])
# Out:
# array([1. , 1. , 0.5])

# %%
rank2nparams.svd / rank2nparams.cp
# Out:
# 1     341.378092
# 2     340.655853
# 3     339.458890
# 4     337.797203
# 5     335.684503
# 6     333.137931
# 7     330.177717
# 8     326.826793
# 9     323.110368
# 10    319.055482
# 11    314.690554
# 12    310.044929
# 13    305.148452
# 14    300.031056
# 15    294.722392
# 16    289.251497
# 17    283.646506
# 18    277.934407
# 19    272.140845
# 20    266.289967
# dtype: float64

# %%
rank2nparams.svd / rank2nparams.tucker
# Out:
# 1     341.378092
# 2     340.655853
# 3     339.458890
# 4     337.797203
# 5     335.684503
# 6     333.137931
# 7     330.177717
# 8     326.826793
# 9     323.110368
# 10    319.055482
# 11    314.690554
# 12    310.044929
# 13    305.148452
# 14    300.031056
# 15    294.722392
# 16    289.251497
# 17    283.646506
# 18    277.934407
# 19    272.140845
# 20    266.289967
# dtype: float64

# %%
### MORE
